# %%
from round import lc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
light_curve = lc.LightCurve.everest("https://archive.stsci.edu/hlsps/everest/v2/c102/201000000/48855/hlsp_everest_k2_llc_201048855-c102_kepler_v2.0_lc.fits");
#%time light_curve.compute()

# %%
fig, axs = plt.subplots(2, 1)
light_curve.plot_raw(axs[0])

# %%
subfig1, axs1 = plt.subplots(2, 1)
subfig2, axs2 = plt.subplots(2, 1)
fig, axs = plt.subplots(1, 2)
light_curve.plot_raw(axs1[0]);
light_curve.plot(axs1[1]);
light_curve.plot_autocor(axs2[0]);
light_curve.plot_map_soln(axs2[1]);
light_curve.plot_corner();
#subfig1.add_subplot(axs1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c751bb3b87e7> in <module>()
#       3 fig, axs = plt.subplots(1, 2)
#       4 light_curve.plot_raw(axs1[0]);
# ----> 5 light_curve.plot(axs1[1]);
#       6 light_curve.plot_autocor(axs2[0]);
#       7 light_curve.plot_map_soln(axs2[1]);
#
# TypeError: plot() takes 1 positional argument but 2 were given

# %%
subfig1, axs = plt.subplots(2, 1)
subfig1.add_subplot(f1.gca())

# %%
light_curve.mcmc_summary
